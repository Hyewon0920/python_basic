# %% [markdown]
# # 고유값과 고유 벡터

# %% [markdown]
# ## 선형 변환
#
# - 벡터공간 두개를 가지고 얘기합니다
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# - L로 매핑시켜줄때 a와b를 결합하나 매핑시키고 결합하나 똑같음
# - 실수배를 먼저하나 나중에 하나 똑같다
# - 0벡터는 변환해도 0벡터
# - 결합법칙처럼 -도 똑같음

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 첫번째 예시는 L(a+b)를 증명
# - 1번과 2번을 만족하기 때문에 L은 선형결합이다

# %% [markdown]
# ## 고유값과 고유벡터
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# - 람다 x로 식정리
# - 람다 x에 x2집어넣기
# - 람다는 허수가 나옴..
# - 근데 선형변환은 실수 상에서 (R제곱) 일어나는 일이므로 i 밸류 없음

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - -람다+1...<<이 행렬의 역행렬이 존재하면 x1 과 x2는 0이 나옴
# - 근데 x1x2는 0이 아닌 벡터라서 앞의 애가 역행렬이 존재하지 않는다.
# - 역행렬이 존재하지 않는다는 의미는 det(P)가 0이라는 뜻
# - det(P)가 0인 상태에서 2x2의 행렬의 역행렬은 ad*bc임 (x자로 곱하고 더하기)
# - 그래서 우측 첫번째 식이 나옴.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 우측 파란글씨처럼 만들 수 있음 근데 람다는 실수고 A는 행렬이므로 람다에 항등행렬을 붙여서 x를 꺼냄. X는 0이 아닌 행렬이므로 앞의 식이 0이어야 함 그래서
# ![image-2.png](attachment:image-2.png)
# 이런식이 나올 수 있음

# %% [markdown]
# ## 사용
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 대각화
#
# ### 유사성
# ![image.png](attachment:image.png)
#
# - B와 A는 유사하다고 얘기함

# %% [markdown]
# ## 대각화
#
# ![image.png](attachment:image.png)
#
#
# - 유사하게 나온 B가 대각행렬이 되면 대각화를 할 수 있다
# - P의 각각의 열벡터들이 V의 베이시스가 됨
# - 복잡한 행렬을 가지고 조금 더 간단화해서 분해할 수 있다는 장점이 있음
#
# ### 성질
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ## 특이값 분해
#
# - A가 nxn인 행렬일때 앞선 분해가 가능했음
# - 특이값분해는 정사각 행렬이 아니어도 가능
# - U랑 V는 정사각행렬로 나누어짐
# - m<n일 때, 시그마가 n개 있고 우측으로 0이 많음 m>n일때 시그마 n개있고 하단으로 0이 더 많음
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# - 단, rank A =r(r<m,n)경우
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## U랑 시그마 V로 나누는 방법
#
# - U에 대해 대각화한다. -> 우선 정사각 행렬로 만들어야 함
# - 람다는 항상 0보다 크다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 사용
#
# ![image.png](attachment:image.png)
#
# - 영향이 있는 값들만 남김

# %% [markdown]
# ## 정부호 행렬
#
# ![image.png](attachment:image.png)
#
# - 이차식이 나오기 때문에 xtAx<< 이런식이 나오게 됨
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 사용
#
# ![image.png](attachment:image.png)
