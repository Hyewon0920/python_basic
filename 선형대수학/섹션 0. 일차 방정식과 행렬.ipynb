# %% [markdown]
# # 1. 선형대수 입문

# %% [markdown]
# ## 1) 머신러닝 입문
#
# - 필요한 지식
# ![image.png](attachment:image.png)
#
# - 분야지식 : 어느곳에 알고리즘을 적용해야 하는지, 원하는 결과를 위해 어디를 전처리 해야하는지
# - 컴퓨터 과학 : 프로그래밍을 통해 구현하는 지
# - 수학 : 알고리즘의 기초가 되는 학문

# %% [markdown]
# ## 선형대수를 배우는 이유 : 행렬
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) 일차방정식과 행렬
#
# - 일차방정식
# ![image.png](attachment:image.png)
#
# #### 특징
#
# 1. 해가 여러개 존재할 수 있다.
# 2. 보통 대입을 통해 품

# %% [markdown]
# ## 3) 행렬의 연산
#
# ![image.png](attachment:image.png)
#
# ### 특징
# #### 1. 열이 1개거나 행이 1개인 애들은 벡터라고 부름
# #### 2. 원소가 다 0인 벡터를 0벡터, 원소가 다 0인 행렬을 영행렬이라고 부름
# ![image-2.png](attachment:image-2.png)
# #### 3. 행렬이 단순한 하나의 숫자로 이루어져있다면(열, 행이 다 1이면) 스칼라라고부름
#
# ### 행렬 읽는 법
# ![image-3.png](attachment:image-3.png)
#
# #### 1. 3행 3열이면 3by3이라고읽음
#
# ### 성질
# ![image-4.png](attachment:image-4.png)
#
# #### 1. 같은행렬 : 크기가 같다. 행과 열 개수가 같다.
#
# ### 연산 방법
#
# #### 1. 같은 위치에 있는 것들과 덧셈뺄셈해주기
#
# ![image-5.png](attachment:image-5.png)
#
# #### 2. 모든 성분에 같은 수를 곱하는게 행렬의 실수배
#
# ![image-6.png](attachment:image-6.png)
#
# #### 3. 곱셈할 때는 p가 같아야 함!!! 곱셈의 교환법칙 성립안함
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
#
# ### 예시
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ## 4) 전치행렬
#
# ![image.png](attachment:image.png)
#
# 1. a21이었으면 a12가 되는 형식
#
# ## 5) 벡터의 내적
#
# ### 같은 자리끼리 더해주면 됨!
# ### 행렬과 벡터의 곱은?
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 6) 일차방정식과 행렬
#
# #### 둘은 서로 치환이 가능하다!
#
# ![image.png](attachment:image.png)
