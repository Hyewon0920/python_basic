# %% [markdown]
# # 1. 행렬
#
# ## 1) 행렬연산성질
#
#
# *곱셈을 하면 교환법칙이 성립안함. 앞 뒤를 조심해라 ca와 ac는 다름! 단, 항등행렬이랑은 성립함
#
# *T의 의미 : 전치해라
#
# ![image-5.png](attachment:image-5.png)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)
#
# #### 다음 명제는 성립하지 않는다 = 여기 나온 모든 식은 틀렸다
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 2) 행렬의 종류
#
# ### I3 머 이런식이면 3바이3의 항등행렬이란 뜻
#
# *상삼각 : 아래쪽 삼각형이 0
#
# *하삼각 : 위쪽 삼각형이 0
#
# *대칭 : 대각선을 기준으로 똑같은 자리에 있는 것들이 같음
#
# *교대대칭 : 대칭과 비슷한데 부호가 다름
#
# *부분행렬 : 행렬의 부분을 나타냄
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
#
#
#
#
#
#
# ### 주요 성질
#
# ![image-2.png](attachment:image-2.png)
#
#
# #### A와 B가 부분행렬이어도 둘을 곱할 땐 행렬곱셈처럼 해주면 됨
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 역행렬
#
# ![image-5.png](attachment:image-5.png)
#
# ### 주요성질 : 역순이 된다
#
# ![image.png](attachment:image.png)
#
# ### determinant**중요 : 이걸통해 역행렬이 존재하는지 유무 find
#
# det(A)이런식으로 씀
#
# - 역행렬이 존재하면 det(A) =/= 0
# - 역행렬이 존재하지 않으면 det(A) =0
#
# #### 성질
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 행렬변환 : 차원을 바꿔줌
#
# ![image.png](attachment:image.png)
#
# ### 예시
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 행렬식 풀이
#
#
# #### 항등행렬은 자기 자신이 나오게 한다
#
# #### -1을 곱해서 위아래 식을 뺄셈할 수도 있다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### 뭔가 이렇게 저렇게 해서 최종적으로 나온 저 식을 row echelon~라고 부름
#
# #### 쟤의 특징은 위와 같음
#
# #### 아래와 같은 식은 존재하지 않음(왜냐, 맨 아래의 식은 다 0이어야하는데 3이 있어서)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## equivalent는 중요함 왜? 간단하게 바꿔줄 수 있으니까
#
# ![image-2.png](attachment:image-2.png)
